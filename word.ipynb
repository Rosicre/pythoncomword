# %%
from docx import Document

# Criando Documento no Python      
documento = Document()

# Aqui você edita tudo que você quer.

faturamento = 1000

texto = f"""Fala Ferreira

Beleza? O Faturamento da Empresa ontem foi de R$ {faturamento}


Tamo Junto, abraço.

"""

paragrafo = documento.add_paragraph(texto)

# %% [markdown]
# #### Formatação

# %%
from docx.shared import Pt, RGBColor, Cm # Valores de Formatação
from docx.enum.style import WD_STYLE_TYPE

paragrafo.style = documento.styles.add_style('EstiloFerreira', WD_STYLE_TYPE.PARAGRAPH)
paragrafo.style.font.name = 'Algerian'
paragrafo.style.font.size = Pt(15)
paragrafo.style.font.bold = True
paragrafo.style.font.italic = True
paragrafo.style.font.underline = True
paragrafo.style.font.color.rgb = RGBColor(255, 0, 0)

# %%
paragrafo = documento.add_paragraph('PS: A quantidade vendida foi de 10 unidades', 'EstiloFerreira')

# %%
# Implementando tudo que fizemos no Python no Texto.docx
documento.save('Texto.docx')

# %% [markdown]
# #### Aproveitando um Template do Word

# %%
template = Document('template.docx')

# %%
paragrafo = template.add_paragraph('Contrato de Prestação de Serviço', 'NovoEstiloFerreira')
template.save('NovoArquivo.docx')

# %% [markdown]
# #### Adicionar texto com edição dentro do texto

# %%
from docx import Document

# Criando Documento no Python      
documento = Document()

# Aqui você edita tudo que você quer.

faturamento = 1000

texto = f"""Fala Ferreira

O Faturamento da Empresa ontem foi de """
texto_final = 'Tamos Juntos, abs.'

paragrafo = documento.add_paragraph(texto)
paragrafo.add_run(f'R$ {faturamento}').bold=True

texto_final = documento.add_paragraph(texto_final)
documento.save('Texto.docx')

# %% [markdown]
# #### Controle de Margem e Seções

# %%
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT

# criando o documento no Python
documento = Document()

for secao in documento.sections:
    secao.top_margin = Cm(0.5)
    secao.bottom_margin = Cm(1)
    secao.left_margin = Cm(1)
    secao.right_margin = Cm(1)


faturamento = 1000

# aqui você edita tudo o que você quer
texto = f"""Fala Ferreira

O faturamento da empresa ontem foi de R${faturamento}

Tamo junto, abs.
"""

paragrafo = documento.add_paragraph(texto) 
paragrafo.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER

documento.save("Texto.docx")

# %% [markdown]
# #### Inserir Imagem

# %%
# criando o documento no Python
documento = Document()

for secao in documento.sections:
    secao.top_margin = Cm(0.5)
    secao.bottom_margin = Cm(1)
    secao.left_margin = Cm(1)
    secao.right_margin = Cm(1)


faturamento = 1000

# aqui você edita tudo o que você quer
texto = f"""Fala Ferreira

O faturamento da empresa ontem foi de R${faturamento}

Tamo junto, abs.
"""

paragrafo = documento.add_paragraph(texto) 
documento.add_picture('imagem.png', width=Cm(4), height=Cm(4))


documento.save("Texto.docx")

# %% [markdown]
# #### Inserir Tabela

# %%
documento = Document()

records = (
    (3,'101','Span'),
    (7,'422','Eggs'),
    (4,'631','Span, span, eggs, and spam')

)

table = documento.add_table(rows=1, cols=3, style = 'Light Grid Accent 1')
hdr_cells = table.rows[0].cells
hdr_cells[0].text ='Qty'
hdr_cells[1].text ='Id'
hdr_cells[2].text ='Desc'

for qty, id, desc in records:
    row_cells = table.add_row().cells
    row_cells[0].text = str(qty)
    row_cells[1].text = id
    row_cells[2].text = desc

documento.save('Texto.docx')

# %% [markdown]
# #### Para Verificar Todos os Estilos de um Arquivo

# %%
for estilo in documento.styles:
    print(estilo)
# Out:
# _ParagraphStyle('Normal') id: 1664739239344
# _ParagraphStyle('Header') id: 1664739238000
# <docx.styles.style._CharacterStyle object at 0x000001839A30EEB0>
# _ParagraphStyle('Footer') id: 1664739238480
# <docx.styles.style._CharacterStyle object at 0x000001839A30EC10>
# _ParagraphStyle('Heading 1') id: 1664739240448
# _ParagraphStyle('Heading 2') id: 1664822811952
# _ParagraphStyle('Heading 3') id: 1664822810032
# _ParagraphStyle('Heading 4') id: 1664822811088
# _ParagraphStyle('Heading 5') id: 1664822810320
# _ParagraphStyle('Heading 6') id: 1664822809984
# _ParagraphStyle('Heading 7') id: 1664822811472
# _ParagraphStyle('Heading 8') id: 1664822811664
# _ParagraphStyle('Heading 9') id: 1664822809600
# <docx.styles.style._CharacterStyle object at 0x000001839F2C1DF0>
# _TableStyle('Normal Table') id: 1664822811136
# <docx.styles.style._NumberingStyle object at 0x000001839F2C11C0>
# _ParagraphStyle('No Spacing') id: 1664822808832
# <docx.styles.style._CharacterStyle object at 0x000001839F2C1BB0>
# <docx.styles.style._CharacterStyle object at 0x000001839F2C1190>
# <docx.styles.style._CharacterStyle object at 0x000001839F2C1B80>
# _ParagraphStyle('Title') id: 1664822810272
# <docx.styles.style._CharacterStyle object at 0x000001839F2C1C40>
# _ParagraphStyle('Subtitle') id: 1664739240832
# <docx.styles.style._CharacterStyle object at 0x000001839A30E0D0>
# _ParagraphStyle('List Paragraph') id: 1664739239104
# _ParagraphStyle('Body Text') id: 1664739241312
# <docx.styles.style._CharacterStyle object at 0x000001839A30E1C0>
# _ParagraphStyle('Body Text 2') id: 1664822810080
# <docx.styles.style._CharacterStyle object at 0x000001839D308850>
# _ParagraphStyle('Body Text 3') id: 1664822810080
# <docx.styles.style._CharacterStyle object at 0x000001839F2C14C0>
# _ParagraphStyle('List') id: 1664822809264
# _ParagraphStyle('List 2') id: 1664822811280
# _ParagraphStyle('List 3') id: 1664822808736
# _ParagraphStyle('List Bullet') id: 1664822811184
# _ParagraphStyle('List Bullet 2') id: 1664822808688
# _ParagraphStyle('List Bullet 3') id: 1664822808640
# _ParagraphStyle('List Number') id: 1664822812240
# _ParagraphStyle('List Number 2') id: 1664822810704
# _ParagraphStyle('List Number 3') id: 1664822812480
# _ParagraphStyle('List Continue') id: 1664822809312
# _ParagraphStyle('List Continue 2') id: 1664822809888
# _ParagraphStyle('List Continue 3') id: 1664822812000
# _ParagraphStyle('macro') id: 1664822810992
# <docx.styles.style._CharacterStyle object at 0x000001839F2C1310>
# _ParagraphStyle('Quote') id: 1664822812288
# <docx.styles.style._CharacterStyle object at 0x000001839F2C10D0>
# <docx.styles.style._CharacterStyle object at 0x000001839F2C1E20>
# <docx.styles.style._CharacterStyle object at 0x000001839F2C17F0>
# <docx.styles.style._CharacterStyle object at 0x000001839F2C1190>
# <docx.styles.style._CharacterStyle object at 0x000001839F2C1A90>
# <docx.styles.style._CharacterStyle object at 0x000001839F2C10A0>
# <docx.styles.style._CharacterStyle object at 0x000001839F2C1A30>
# _ParagraphStyle('Caption') id: 1664822808688
# <docx.styles.style._CharacterStyle object at 0x000001839F2C1040>
# <docx.styles.style._CharacterStyle object at 0x000001839F2C1E50>
# _ParagraphStyle('Intense Quote') id: 1664822812000
# <docx.styles.style._CharacterStyle object at 0x000001839F2C1970>
# <docx.styles.style._CharacterStyle object at 0x000001839F2C1310>
# <docx.styles.style._CharacterStyle object at 0x000001839F2C1970>
# <docx.styles.style._CharacterStyle object at 0x000001839F2C1F70>
# <docx.styles.style._CharacterStyle object at 0x000001839F2C1070>
# <docx.styles.style._CharacterStyle object at 0x000001839F2C1640>
# _ParagraphStyle('TOC Heading') id: 1664822812288
# _TableStyle('Table Grid') id: 1664822808784
# _TableStyle('Light Shading') id: 1664822812192
# _TableStyle('Light Shading Accent 1') id: 1664822811664
# _TableStyle('Light Shading Accent 2') id: 1664822811472
# _TableStyle('Light Shading Accent 3') id: 1664822811328
# _TableStyle('Light Shading Accent 4') id: 1664822809408
# _TableStyle('Light Shading Accent 5') id: 1664822810368
# _TableStyle('Light Shading Accent 6') id: 1664822809984
# _TableStyle('Light List') id: 1664822810320
# _TableStyle('Light List Accent 1') id: 1664822811088
# _TableStyle('Light List Accent 2') id: 1664822810032
# _TableStyle('Light List Accent 3') id: 1664822811952
# _TableStyle('Light List Accent 4') id: 1664822810848
# _TableStyle('Light List Accent 5') id: 1664739238816
# _TableStyle('Light List Accent 6') id: 1664822811952
# _TableStyle('Light Grid') id: 1664822809936
# _TableStyle('Light Grid Accent 1') id: 1664822810032
# _TableStyle('Light Grid Accent 2') id: 1664822811088
# _TableStyle('Light Grid Accent 3') id: 1664822810320
# _TableStyle('Light Grid Accent 4') id: 1664822809984
# _TableStyle('Light Grid Accent 5') id: 1664822810368
# _TableStyle('Light Grid Accent 6') id: 1664822809408
# _TableStyle('Medium Shading 1') id: 1664822811328
# _TableStyle('Medium Shading 1 Accent 1') id: 1664822811472
# _TableStyle('Medium Shading 1 Accent 2') id: 1664822811664
# _TableStyle('Medium Shading 1 Accent 3') id: 1664822812192
# _TableStyle('Medium Shading 1 Accent 4') id: 1664822808784
# _TableStyle('Medium Shading 1 Accent 5') id: 1664822812288
# _TableStyle('Medium Shading 1 Accent 6') id: 1664822810176
# _TableStyle('Medium Shading 2') id: 1664822808688
# _TableStyle('Medium Shading 2 Accent 1') id: 1664822812528
# _TableStyle('Medium Shading 2 Accent 2') id: 1664822810992
# _TableStyle('Medium Shading 2 Accent 3') id: 1664822812528
# _TableStyle('Medium Shading 2 Accent 4') id: 1664822808688
# _TableStyle('Medium Shading 2 Accent 5') id: 1664822810176
# _TableStyle('Medium Shading 2 Accent 6') id: 1664822812288
# _TableStyle('Medium List 1') id: 1664822808784
# _TableStyle('Medium List 1 Accent 1') id: 1664822812192
# _TableStyle('Medium List 1 Accent 2') id: 1664822811664
# _TableStyle('Medium List 1 Accent 3') id: 1664822811472
# _TableStyle('Medium List 1 Accent 4') id: 1664822811328
# _TableStyle('Medium List 1 Accent 5') id: 1664822809408
# _TableStyle('Medium List 1 Accent 6') id: 1664822810368
# _TableStyle('Medium List 2') id: 1664822809984
# _TableStyle('Medium List 2 Accent 1') id: 1664822810320
# _TableStyle('Medium List 2 Accent 2') id: 1664822811088
# _TableStyle('Medium List 2 Accent 3') id: 1664822810032
# _TableStyle('Medium List 2 Accent 4') id: 1664822809936
# _TableStyle('Medium List 2 Accent 5') id: 1664822811952
# _TableStyle('Medium List 2 Accent 6') id: 1664739238816
# _TableStyle('Medium Grid 1') id: 1664739240544
# _TableStyle('Medium Grid 1 Accent 1') id: 1664739241408
# _TableStyle('Medium Grid 1 Accent 2') id: 1664739241120
# _TableStyle('Medium Grid 1 Accent 3') id: 1664739238912
# _TableStyle('Medium Grid 1 Accent 4') id: 1664739239056
# _TableStyle('Medium Grid 1 Accent 5') id: 1664739240976
# _TableStyle('Medium Grid 1 Accent 6') id: 1664739238480
# _TableStyle('Medium Grid 2') id: 1664739241648
# _TableStyle('Medium Grid 2 Accent 1') id: 1664822809360
# _TableStyle('Medium Grid 2 Accent 2') id: 1664822810896
# _TableStyle('Medium Grid 2 Accent 3') id: 1664822810128
# _TableStyle('Medium Grid 2 Accent 4') id: 1664822812048
# _TableStyle('Medium Grid 2 Accent 5') id: 1664822810512
# _TableStyle('Medium Grid 2 Accent 6') id: 1664822811040
# _TableStyle('Medium Grid 3') id: 1664822809216
# _TableStyle('Medium Grid 3 Accent 1') id: 1664822811712
# _TableStyle('Medium Grid 3 Accent 2') id: 1664822810464
# _TableStyle('Medium Grid 3 Accent 3') id: 1664822812624
# _TableStyle('Medium Grid 3 Accent 4') id: 1664822809312
# _TableStyle('Medium Grid 3 Accent 5') id: 1664822809264
# _TableStyle('Medium Grid 3 Accent 6') id: 1664822811568
# _TableStyle('Dark List') id: 1664822808832
# _TableStyle('Dark List Accent 1') id: 1664822809024
# _TableStyle('Dark List Accent 2') id: 1664822809600
# _TableStyle('Dark List Accent 3') id: 1664822812144
# _TableStyle('Dark List Accent 4') id: 1664739240880
# _TableStyle('Dark List Accent 5') id: 1664739240976
# _TableStyle('Dark List Accent 6') id: 1664739239056
# _TableStyle('Colorful Shading') id: 1664739238912
# _TableStyle('Colorful Shading Accent 1') id: 1664739241120
# _TableStyle('Colorful Shading Accent 2') id: 1664739241408
# _TableStyle('Colorful Shading Accent 3') id: 1664739240544
# _TableStyle('Colorful Shading Accent 4') id: 1664739238816
# _TableStyle('Colorful Shading Accent 5') id: 1664739238192
# _TableStyle('Colorful Shading Accent 6') id: 1664739238576
# _TableStyle('Colorful List') id: 1664789547472
# _TableStyle('Colorful List Accent 1') id: 1664789547184
# _TableStyle('Colorful List Accent 2') id: 1664739238000
# _TableStyle('Colorful List Accent 3') id: 1664739240544
# _TableStyle('Colorful List Accent 4') id: 1664739241408
# _TableStyle('Colorful List Accent 5') id: 1664739241120
# _TableStyle('Colorful List Accent 6') id: 1664739238912
# _TableStyle('Colorful Grid') id: 1664739239056
# _TableStyle('Colorful Grid Accent 1') id: 1664739240976
# _TableStyle('Colorful Grid Accent 2') id: 1664739240880
# _TableStyle('Colorful Grid Accent 3') id: 1664739238480
# _TableStyle('Colorful Grid Accent 4') id: 1664822811136
# _TableStyle('Colorful Grid Accent 5') id: 1664822812000
# _TableStyle('Colorful Grid Accent 6') id: 1664822812240

# %% [markdown]
# #### Adaptar um Documento

# %%
from datetime import datetime
import time

contrato = Document('Contrato.docx')

nome = "Rosicre Ferreira"
item1 = "Serviço de Treinamento em Python"
item2 = "Apostila Completa de SQL"
item3 = "Serviço de Treinamentos de Power Bi"

dicionario_valores = {
    'XXXX':nome,
    "YYYY":item1,
    'ZZZZ':item2,
    'WWWW':item3,
    'DD':str(datetime.now().day), 
    'MM':str(datetime.now().month),
    'AAAA': str(datetime.now().year),

}

# tem alguma função replace? -> é executada por parágrafo
# percorrer as linhas
    # se a linha tiver o texto xxxx substitui pelo nome

for paragrafo in contrato.paragraphs:
    # Para cada placeholder do dicionário
    for codigo in dicionario_valores:
        if codigo in paragrafo.text:
            paragrafo.text = paragrafo.text.replace(codigo, dicionario_valores[codigo])

contrato.save('Contrato Atualizado.docx')
